# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 다운받을때 아래처럼 SAVE_PATH에서 .zip으로 명시해줘야 함.
# 명시하지 않고 그냥 다운받으면 Zendo사이트에서 files-archive로 저장되면서 unziip같은 툴이 이게 zip파일이 맞는지 헷갈려하면서 툴에 따라 에러가 날수있다.

# %%
# %cd /content/drive/MyDrive/OK_individual_project/DIPS_Plus_data/
# Out:
# /content/drive/MyDrive/OK_individual_project/DIPS_Plus_data

# %%
# !pwd
# Out:
# /content/drive/MyDrive/OK_individual_project/DIPS_Plus_data

# %%
# !git clone https://github.com/BioinfoMachineLearning/DIPS-Plus.git
# Out:
# Cloning into 'DIPS-Plus'...
# remote: Enumerating objects: 708, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 708 (delta 142), reused 203 (delta 117), pack-reused 463 (from 1)
# Receiving objects: 100% (708/708), 1.45 MiB | 5.11 MiB/s, done.
# Resolving deltas: 100% (407/407), done.

# %%
SAVE_DIR="/content/drive/MyDrive/OK_individual_project/DIPS_Plus_data"

# DIPS-Plus v1.3.0
# -c(continue): 중단된 다운로드 이어받기, 만약 colab이나 네트워크 끊겼을 때 파일 일부가 이미 저장되어 있으면, 그 위치부터 이어서 받아준다.
# -P(prefix): 다운로드 받은 파일을 저장할 폴더 경로를 지정.
# !wget -c -P "$SAVE_DIR" "https://zenodo.org/records/8140981/files/final_raw_dips.tar.gz"
# Out:
# --2025-09-11 10:53:45--  https://zenodo.org/records/8140981/files/final_raw_dips.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15693946010 (15G) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/OK_individual_project/DIPS_Plus_data/final_raw_dips.tar.gz’
#
# final_raw_dips.tar. 100%[===================>]  14.62G  2.03MB/s    in 2h 13m
#
# 2025-09-11 13:07:21 (1.87 MB/s) - ‘/content/drive/MyDrive/OK_individual_project/DIPS_Plus_data/final_raw_dips.tar.gz’ saved [15693946010/15693946010]

# %%
# (선택) MSA HDF5 묶음
# MSA(Multiple Sequence Alignment): 여러 단백질 서열을 정렬해서 진화적, 보존적 특징을 뽑는 방법
# DIPS-Plus에서는 각 단백질 체인에 대해 Jackhmmer(UniRef90 DB)와 AlphaFold BFD 서브샘플을 써서 MSA를 만들었음
# 이 정보를 HDF5포멧으로 저장해둔게 interim_external_feates_dips_mas.tar.gz
# !wget -c -P "$SAVE_DIR" "https://zenodo.org/records/8140981/files/interim_external_feats_dips_msas.tar.gz"

# 2) DB5-Plus raw (벤치마크용, v1.1.0)
# 구조적으로 독립적인 단백질 쌍이 많아, DIPS-Plus에서 본적 없는 새로운 조합을 예측하는 역할(검증용)
# !wget -c -P "$SAVE_DIR" "https://zenodo.org/records/5134732/files/final_raw_db5.tar.gz"
# Out:
# --2025-09-11 13:22:48--  https://zenodo.org/records/8140981/files/interim_external_feats_dips_msas.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11991056916 (11G) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/OK_individual_project/DIPS_Plus_data/interim_external_feats_dips_msas.tar.gz’
#
# interim_external_fe 100%[===================>]  11.17G  2.60MB/s    in 64m 43s
#
# 2025-09-11 14:27:32 (2.94 MB/s) - ‘/content/drive/MyDrive/OK_individual_project/DIPS_Plus_data/interim_external_feats_dips_msas.tar.gz’ saved [11991056916/11991056916]
#
# --2025-09-11 14:27:32--  https://zenodo.org/records/5134732/files/final_raw_db5.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# ...
